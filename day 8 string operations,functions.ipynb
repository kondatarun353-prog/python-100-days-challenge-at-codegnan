# %%
s= "codegnan"

# %%
print(s)
# Out:
# codegnan

# %% [markdown]
# # stringoperation
# ## concatination +
# ### repetation *

# %% [markdown]
# # stringconcatination

# %%
s1="code"
s2="gnan"
s3=s1+s2
print(s3)
# Out:
# codegnan

# %% [markdown]
# # stringrepeat

# %%
s="codegnan"
print((" " +s)*3)
# Out:
#  codegnan codegnan codegnan

# %% [markdown]
# # stringfunctions
# ### case convertionfunctons - lower(),upper(),title(),swapcase(),capitalize()

# %%
s="i aM a pytHon Trainee"
print(s.lower())
print(s.upper())
print(s.title())
print(s.swapcase())
print(s.capitalize())
# Out:
# i am a python trainee
# I AM A PYTHON TRAINEE
# I Am A Python Trainee
# I Am A PYThON tRAINEE
# I am a python trainee

# %% [markdown]
# # substring index finding
# # find()

# %%
s="my name is tarun from mlrit"
print(s.find("t"))
print(s.find("t",15))#starts checking from 15th place
# Out:
# 11
# 26

# %% [markdown]
# # strip()
# ### removes the white spaces

# %%
s="@@code#@gnan  @@@##"
print(s)
print(s.strip())
print(s.strip("@"))
print(s.rstrip("@"))
print(s.lstrip("#"))
# Out:
# @@code#@gnan  @@@##
# @@code#@gnan  @@@##
# code#@gnan  @@@##
# @@code#@gnan  @@@##
# @@code#@gnan  @@@##

# %%
s=" i am a python trainee"
print(s.split())
# Out:
# ['i', 'am', 'a', 'python', 'trainee']

# %% [markdown]
# # case checking functions

# %%
s1="codegnan"
s2="CODEGNAN"
s3="123 " #here we have whitespace
s4="abc123"
s5="COdegnan"
s6="1234"
print(s1.isupper())
print(s5.islower())
print(s3.isdigit())
print(s6.isdigit())
print(s4.isalnum())  #number or alphabet
print(s5.isalpha())
# Out:
# False
# False
# False
# True
# True
# True

# %%
"t" in "tarun"
# Out:
# True

# %%
"s" in "tarun"
# Out:
# False
