# %%
#find length of number without length function
n=123
count=0
while n > 0:
    n=n//10
    count+=1
print(count)
# Out:
# 3

# %%
#length of negative number
n=-1235484
count=0
if n==0:
    print(1)
elif n<0:
    n=-n
count=0
while n>0:
    n=n//10
    count+=1
print(count)
# Out:
# 7

# %%
#sum of digits of a number 123 =6
n=123
s=0
while n>0:
    digit=n%10
    n=n//10
    s=s+digit
print(s)
# Out:
# 6

# %%
n=-123678
s=0
if n<0:
    n=-n
while n>0:
    digit=n%10
    n=n//10
    s=s+digit
print(s)
# Out:
# 27

# %%
#reverse a number - palindromeof a number 121
n=123
s=0
while n>0:
    digit=n%10
    n=n//10
    s=s*10+digit
print(s)
# Out:
# 321

# %%
# palindrome of a number(121) = (121)
n=121
s=0
temp=n
while n>0:
    digit=n%10
    n=n//10
    s=s*10+digit
print(s)
if s==temp:
    print("palindrome")
else: 
    print("not a palindrome")
# Out:
# 121
# palindrome

# %%
# Python program to check if the number is an Armstrong number or not
num = int(input())
sum = 0
temp = num
while temp > 0:
   digit = temp % 10
   sum += digit ** 3
   temp //= 10
if num == sum:
   print(num,"is an Armstrong number")
else:
   print(num,"is not an Armstrong number")
# Out:
#  407
# 407 is an Armstrong number

# %%
# len and rev a string
a="abc"
rev=""
for i in a:
    rev=i+rev
print(rev)
# Out:
# cba

# %%
a="abc"
count=0
for i in a:
    count=count+1
print(count)
# Out:
# 3

# %% [markdown]
# #
