# %%
# FIND string length without using len()
a=input()
def len_of_string(a):
    counter = 0
    for _ in a:
        counter=counter+1
        print(counter)
len_of_string(a)
# Out:
#  tarun
# 1
# 2
# 3
# 4
# 5
